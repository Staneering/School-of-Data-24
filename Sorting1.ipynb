# %% [markdown]
# <a href="https://colab.research.google.com/github/Staneering/School-of-Data-24/blob/main/Sorting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
impo

# %% [markdown]
# ## Learning Objectives:
# By the end of this, you should be able to:
#
# * Sort and filter Pandas dataframes;
# * Create and delete columns in Pandas dataframes; and
#
#
# ## Outline:
# We will:
#
# * Use the football players dataset;
# * Manipulate Pandas dataframes through sorting and filtering;
# * Alter Pandas dataframes by creating and deleting columns;

# %% [markdown]
# ## Introduction
#
# When a dataset only has a few data points, it's very easy to manually apply operations to the entire dataset. However, good datasets are very rarely this small. The Pandas library in Python allows us to use vectorised operations (i.e. operations across multiple data points simultaneously), making it much easier to work with large amounts of data.
#
# In this train, we look at how to manipulate data within dataframes. Let's start by importing the Pandas library and the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fifa (1).csv')
# Out:
# <ipython-input-2-b77f35a7f821>:1: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('fifa (1).csv')

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo   32    Portugal       94       89         63
# 1           L. Messi   30   Argentina       93       92         48
# 2             Neymar   25      Brazil       92       94         56
# 3          L. Suárez   30     Uruguay       92       88         78
# 4           M. Neuer   31     Germany       92       58         29
#
#   Agility Balance Ball control Composure  ... Short passing Shot power  \
# 0  89      63           93        95      ...        83         94
# 1  90      95           95        96      ...        88         85
# 2  96      82           95        92      ...        81         80
# 3  86      60           91        83      ...        83         87
# 4  52      35           48        70      ...        55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0         23           91      92              31       80      85
# 1         26           87      73              28       59      90
# 2         33           90      78              24       53      80
# 3         38           77      89              45       80      84
# 4         11           61      44              10       83      70
#
#   Volleys Preferred Positions
# 0  88                  ST LW
# 1  85                     RW
# 2  83                     LW
# 3  88                     ST
# 4  11                     GK
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
#        'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
#        'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
#        'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
#        'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
#        'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys',
#        'Preferred Positions'],
#       dtype='object')

# %% [markdown]
# Sorting
#
# One basic operation to perform when working with a large dataset is to sort the values using some criteria. For dataframes, sorting can be achieved by using the sort_values() function. To sort data entries by a specific column(s), we need to pass this column(s) to the function. Let's look at some examples:

# %%
df.sort_values('Overall',ascending=False)
# Out:
#                     Name  Age Nationality  Overall Acceleration Aggression  \
# 0      Cristiano Ronaldo   32    Portugal       94       89         63
# 1               L. Messi   30   Argentina       93       92         48
# 2                 Neymar   25      Brazil       92       94         56
# 3              L. Suárez   30     Uruguay       92       88         78
# 4               M. Neuer   31     Germany       92       58         29
# ...                  ...  ...         ...      ...          ...        ...
# 17976          A. Kelsey   17     England       46       24         16
# 17977      B. Richardson   47     England       46       25         44
# 17978           J. Young   17    Scotland       46       66         26
# 17979       J. Lundstram   18     England       46       57         46
# 17980          L. Sackey   18       Ghana       46       48         52
#
#       Agility Balance Ball control Composure  ... Short passing Shot power  \
# 0      89      63           93        95      ...        83         94
# 1      90      95           95        96      ...        88         85
# 2      96      82           95        92      ...        81         80
# 3      86      60           91        83      ...        83         87
# 4      52      35           48        70      ...        55         25
# ...       ...     ...          ...       ...  ...           ...        ...
# 17976  38      26           12        23      ...        19         19
# 17977  35      44           22        44      ...        12         13
# 17978  60      77           41        50      ...        42         42
# 17979  58      74           43        45      ...        49         43
# 17980  49      47           32        33      ...        31         21
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0             23           91      92              31       80      85
# 1             26           87      73              28       59      90
# 2             33           90      78              24       53      80
# 3             38           77      89              45       80      84
# 4             11           61      44              10       83      70
# ...              ...          ...     ...             ...      ...     ...
# 17976         10           32      28              11       50      26
# 17977         13           25      32              12       47      17
# 17978         14           51      33              17       32      37
# 17979         47           58      49              48       46      51
# 17980         43           49      55              44       67      22
#
#       Volleys Preferred Positions
# 0      88                  ST LW
# 1      85                     RW
# 2      83                     LW
# 3      88                     ST
# 4      11                     GK
# ...       ...                 ...
# 17976   6                     GK
# 17977  12                     GK
# 17978  33                     ST
# 17979  25                     CM
# 17980  19                  ST CB
#
# [17981 rows x 39 columns]

# %%
df.isna().sum()
# Out:
# Name                   0
# Age                    0
# Nationality            0
# Overall                0
# Acceleration           0
# Aggression             0
# Agility                0
# Balance                0
# Ball control           0
# Composure              0
# Crossing               0
# Curve                  0
# Dribbling              0
# Finishing              0
# Free kick accuracy     0
# GK diving              0
# GK handling            0
# GK kicking             0
# GK positioning         0
# GK reflexes            0
# Heading accuracy       0
# Interceptions          0
# Jumping                0
# Long passing           0
# Long shots             0
# Marking                0
# Penalties              0
# Positioning            0
# Reactions              0
# Short passing          0
# Shot power             0
# Sliding tackle         0
# Sprint speed           0
# Stamina                0
# Standing tackle        0
# Strength               0
# Vision                 0
# Volleys                0
# Preferred Positions    0
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([32, 30, 25, 31, 28, 26, 27, 29, 39, 23, 24, 35, 33, 34, 36, 21, 22,
#        18, 20, 19, 37, 38, 40, 17, 44, 41, 16, 43, 47])

# %%
df['Age'].replace(32,np.nan,inplace=True)

# %%
df['Age']
# Out:
# 0         NaN
# 1        30.0
# 2        25.0
# 3        30.0
# 4        31.0
#          ...
# 17976    17.0
# 17977    47.0
# 17978    17.0
# 17979    18.0
# 17980    18.0
# Name: Age, Length: 17981, dtype: float64

# %%
df.sort_values(by = 'Age',ascending = False)
# Out:
#                     Name   Age  Nationality  Overall Acceleration Aggression  \
# 17977      B. Richardson  47.0      England       46       25         44
# 5314        E. El Hadary  44.0        Egypt       70       28         29
# 4839            O. Pérez  44.0       Mexico       71       60         26
# 16696           D. Coyne  43.0        Wales       55       36         36
# 16834          J. Walker  43.0      England       55       22         41
# ...                  ...   ...          ...      ...          ...        ...
# 16116          M. Sprang  16.0      Germany       57       18         12
# 15571       Javi Vázquez  16.0        Spain       58       61         53
# 15968          E. Håland  16.0       Norway       58       63         67
# 15119      L. Geertruida  16.0  Netherlands       59       72         47
# 0      Cristiano Ronaldo   NaN     Portugal       94       89         63
#
#       Agility Balance Ball control Composure  ... Short passing Shot power  \
# 17977  35      44           22        44      ...        12         13
# 5314   21      41           25        57      ...        16         18
# 4839   69      69           23        50      ...        26         24
# 16696  48      58           31        57      ...        28         21
# 16834  53      64           38        35      ...        22         22
# ...       ...     ...          ...       ...  ...           ...        ...
# 16116  19      29           10        18      ...        19         17
# 15571  48      65           47        43      ...        41         42
# 15968  68      59           57        48      ...        46         56
# 15119  54      66           58        31      ...        60         29
# 0      89      63           93        95      ...        83         94
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 17977         13           25      32              12       47      17
# 5314          15           39      34              19       73      16
# 4839          11           57      41              12       66      40
# 16696         19           33      37              16       76      33
# 16834         13           35      19              11       62      32
# ...              ...          ...     ...             ...      ...     ...
# 16116         13           16      32              14       38      59
# 15571         59           64      59              63       55      37
# 15968         15           73      51              11       66      49
# 15119         57           63      45              62       61      26
# 0             23           91      92              31       80      85
#
#       Volleys Preferred Positions
# 17977  12                     GK
# 5314   12                     GK
# 4839   13                     GK
# 16696  11                     GK
# 16834  11                     GK
# ...       ...                 ...
# 16116  12                     GK
# 15571  29                     CB
# 15968  51                     ST
# 15119  27                  RB CB
# 0      88                  ST LW
#
# [17981 rows x 39 columns]

# %%
df['Age'].fillna(32,inplace=True)

# %% [markdown]
# Filtering

# %%
df[df['Age']==32]
# Out:
#                 Name   Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo  32.0    Portugal       94       89         63
#
#   Agility Balance Ball control Composure  ... Short passing Shot power  \
# 0  89      63           93        95      ...        83         94
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0         23           91      92              31       80      85
#
#   Volleys Preferred Positions
# 0  88                  ST LW
#
# [1 rows x 39 columns]

# %%
df['Rating Per Age']=df['Overall']/df['Age']

df['Rating Per Age']
# Out:
# 0        2.937500
# 1        3.100000
# 2        3.680000
# 3        3.066667
# 4        2.967742
#            ...
# 17976    2.705882
# 17977    0.978723
# 17978    2.705882
# 17979    2.555556
# 17980    2.555556
# Name: Rating Per Age, Length: 17981, dtype: float64

# %%
df['Rating per Age2']=df.apply(lambda x: x['Overall']/x['Age'],axis = 1)

# %%
df['Rating per Age2']
# Out:
# 0        2.937500
# 1        3.100000
# 2        3.680000
# 3        3.066667
# 4        2.967742
#            ...
# 17976    2.705882
# 17977    0.978723
# 17978    2.705882
# 17979    2.555556
# 17980    2.555556
# Name: Rating per Age2, Length: 17981, dtype: float64

# %% [markdown]
# # Deleting Columns

# %%
df.drop(['Rating per Age2','Rating Per Age'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
#        'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
#        'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
#        'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
#        'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
#        'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys',
#        'Preferred Positions', 'Rating Per Age', 'Rating per Age2'],
#       dtype='object')

# %%
df.head()
# Out:
#                 Name   Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo  32.0    Portugal       94       89         63
# 1           L. Messi  30.0   Argentina       93       92         48
# 2             Neymar  25.0      Brazil       92       94         56
# 3          L. Suárez  30.0     Uruguay       92       88         78
# 4           M. Neuer  31.0     Germany       92       58         29
#
#   Agility Balance Ball control Composure  ... Short passing Shot power  \
# 0  89      63           93        95      ...        83         94
# 1  90      95           95        96      ...        88         85
# 2  96      82           95        92      ...        81         80
# 3  86      60           91        83      ...        83         87
# 4  52      35           48        70      ...        55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0         23           91      92              31       80      85
# 1         26           87      73              28       59      90
# 2         33           90      78              24       53      80
# 3         38           77      89              45       80      84
# 4         11           61      44              10       83      70
#
#   Volleys Preferred Positions
# 0  88                  ST LW
# 1  85                     RW
# 2  83                     LW
# 3  88                     ST
# 4  11                     GK
#
# [5 rows x 39 columns]

# %% [markdown]
# # Grouping Values

# %%
df[df['Age']==16]
# Out:
#                 Name   Age     Nationality  Overall Acceleration Aggression  \
# 10556      K. Pierie  16.0     Netherlands       65       72         64
# 10557    Ha Dae Sung  16.0  Korea Republic       65       45         67
# 11397       A. Gomes  16.0         England       64    27546         36
# 13733     E. Vignato  16.0           Italy       61       69         13
# 15063   G. McEachran  16.0         England       59       64         48
# 15119  L. Geertruida  16.0     Netherlands       59       72         47
# 15571   Javi Vázquez  16.0           Spain       58       61         53
# 15837      J. Romero  16.0       Argentina       58       75         36
# 15968      E. Håland  16.0          Norway       58       63         67
# 16116      M. Sprang  16.0         Germany       57       18         12
# 17014    R. Strechie  16.0         Romania       54       64         51
# 17025      L. Pintor  16.0          France       54       72         29
# 17055     V. Barbero  16.0       Argentina       54       73         34
# 17667        J. Hove  16.0          Norway       51       57         57
#
#       Agility Balance Ball control Composure  ... Short passing Shot power  \
# 10556  66      53           65        66      ...        68         35
# 10557  61      63           64        65      ...        66         65
# 11397  82      90           66        57      ...          63+3     61
# 13733  69      69           69        52      ...        68         52
# 15063  72      74           61        63      ...        66         47
# 15119  54      66           58        31      ...        60         29
# 15571  48      65           47        43      ...        41         42
# 15837  70      86           55        59      ...        52         54
# 15968  68      59           57        48      ...        46         56
# 16116  19      29           10        18      ...        19         17
# 17014  63      61           52        47      ...        60         52
# 17025  70      68           56        43      ...        30         57
# 17055  76      77           48        52      ...        50         51
# 17667  58      56           51        42      ...        56         50
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 10556         62           72      45              67       65      56
# 10557         60           51      63              61       68      65
# 11397         20        25842      58              19       34        63+7
# 13733         30           65      59              22       33      52
# 15063         54           62      54              55       36      64
# 15119         57           63      45              62       61      26
# 15571         59           64      59              63       55      37
# 15837         25           77      58              26       41      51
# 15968         15           73      51              11       66      49
# 16116         13           16      32              14       38      59
# 17014         50           61      61              54       62      53
# 17025         12           68      36              10       34      38
# 17055         25           75      60              25       42      48
# 17667         56           64      47              51       54      56
#
#       Volleys Preferred Positions
# 10556  32                  LB CB
# 10557  55                     CM
# 11397    57+1       CM RW LW CAM
# 13733  57                    CAM
# 15063  46                 CM CAM
# 15119  27                  RB CB
# 15571  29                     CB
# 15837  45                     ST
# 15968  51                     ST
# 16116  12                     GK
# 17014  28                     CM
# 17025  48                     ST
# 17055  50                     RM
# 17667  29                     CM
#
# [14 rows x 39 columns]

# %%
df.groupby('Age')['Overall'].mean()
# Out:
# Age
# 16.0    58.357143
# 17.0    56.089147
# 18.0    57.331865
# 19.0    59.506002
# 20.0    61.623131
# 21.0    63.501898
# 22.0    64.818718
# 23.0    66.195362
# 24.0    67.251997
# 25.0    68.038047
# 26.0    68.647718
# 27.0    68.928632
# 28.0    69.077562
# 29.0    69.818966
# 30.0    69.976019
# 31.0    69.873759
# 32.0    94.000000
# 33.0    69.777605
# 34.0    68.978723
# 35.0    69.306122
# 36.0    69.310345
# 37.0    68.666667
# 38.0    68.666667
# 39.0    67.857143
# 40.0    67.625000
# 41.0    64.333333
# 43.0    55.000000
# 44.0    70.500000
# 47.0    46.000000
# Name: Overall, dtype: float64

# %%
max_age_group =df.groupby('Age')['Overall'].max()

# %%
max_age_group.plot(kind = 'bar',figsize=(10,6))

plt.title('Bar Chart of Maximum Overall Rating by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Maximum Overall Rating')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in max(a, axis, out, keepdims, initial, where)
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85             else:
# ---> 86                 return reduction(axis=axis, out=out, **passkwargs)
#      87
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in max(self, axis, skipna, numeric_only, **kwargs)
#    6516     ):
# -> 6517         return NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#    6518
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in max(self, axis, skipna, numeric_only, **kwargs)
#   12403     ):
# > 12404         return self._stat_function(
#   12405             "max",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#    1097         )
# -> 1098         result = getattr(values, meth)(axis)
#    1099         result = _maybe_null_out(result, axis, mask, values.shape)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      42
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c2f21c8f3f44> in <cell line: 1>()
# ----> 1 df.groupby('Age').max()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in max(self, numeric_only, min_count, engine, engine_kwargs)
#    3328             )
#    3329         else:
# -> 3330             return self._agg_general(
#    3331                 numeric_only=numeric_only,
#    3332                 min_count=min_count,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1904         **kwargs,
#    1905     ):
# -> 1906         result = self._cython_agg_general(
#    1907             how=alias,
#    1908             alt=npfunc,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->max,dtype->object]
